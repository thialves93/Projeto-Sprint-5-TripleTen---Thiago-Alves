# %%
import pandas as pd
import plotly.express as px

car_data = pd.read_csv('../vehicles_us.csv') # lendo os dados
print(car_data.info())
display(car_data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103053 entries, 0 to 103052
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         103053 non-null  object
#  1   model_year    95813 non-null   object
#  2   model         103051 non-null  object
#  3   condition     103051 non-null  object
#  4   cylinders     92531 non-null   object
#  5   fuel          103051 non-null  object
#  6   odometer      87267 non-null   object
#  7   transmission  103051 non-null  object
#  8   type          103051 non-null  object
#  9   paint_color   84517 non-null   object
#  10  is_4wd        51145 non-null   object
#  11  date_posted   103051 non-null  object
#  12  days_listed   103051 non-null  object
# dtypes: object(13)
# memory usage: 10.2+ MB
# None
# C:\Users\aathi\AppData\Local\Temp\ipykernel_13568\1041477717.py:4: DtypeWarning:
#
# ...

# %%
# Exemplo do projeto

fig = px.histogram(car_data, x="odometer") # criar um histograma
fig.show() # exibindo
print()
print()
fig = px.scatter(car_data, x="odometer", y="price") # criar um gráfico de dispersão
fig.show() # exibindo

# %%
# Remover carros sem preço definido
car_data_clean = car_data.dropna(subset=['price'])
carros_baratos = car_data_clean.sort_values('price').head(10)
display(carros_baratos)

for col in ["price", "odometer", "model_year", "days_listed"]:
        if col in car_data.columns:
            car_data[col] = pd.to_numeric(car_data[col], errors="coerce")

# Top 5 modelos mais baratos
top5_price = car_data.nsmallest(5, 'price')[['model', 'price']]
print(top5_price)
# Out:
#       price model_year                model  condition cylinders fuel  \
# 19445     1     2003.0     chevrolet malibu       good         6  gas
# 68520     1     2015.0      gmc sierra 1500  excellent      10.0  gas
# 10886     1     2015.0  jeep grand cherokee  excellent         8  gas
# 16741     1     2016.0        toyota tundra  excellent         8  gas
# 16742     1     2017.0        jeep wrangler  excellent        10  gas
# 10885     1     2014.0             ram 2500  excellent         6  gas
# 10884     1     2014.0       toyota 4runner  excellent         6  gas
# 48867     1     2014.0        jeep wrangler  excellent        10  gas
# 16743     1     2012.0        jeep wrangler  excellent         6  gas
# 16745     1     2015.0             ram 3500  excellent         6  gas
#
#        odometer transmission   type paint_color is_4wd date_posted days_listed
# 19445  190000.0    automatic  sedan         NaN    NaN  2018-11-20          51
# ...

# %%
# Valores únicos em ordem crescente
precos_ordenados = sorted(car_data['price'].unique())
print(precos_ordenados)
# Out:
# [np.float64(1.0), np.float64(3.0), np.float64(5.0), np.float64(6.0), np.float64(9.0), np.float64(10.0), np.float64(11.0), np.float64(12.0), np.float64(15.0), np.float64(20.0), np.float64(24.0), np.float64(25.0), np.float64(28.0), np.float64(32.0), np.float64(35.0), np.float64(36.0), np.float64(39.0), np.float64(65.0), np.float64(69.0), np.float64(80.0), np.float64(85.0), np.float64(105.0), np.float64(111.0), np.float64(147.0), np.float64(155.0), np.float64(169.0), np.float64(171.0), np.float64(176.0), np.float64(179.0), np.float64(180.0), np.float64(185.0), np.float64(187.0), np.float64(188.0), np.float64(190.0), np.float64(195.0), np.float64(196.0), np.float64(197.0), np.float64(198.0), np.float64(199.0), np.float64(200.0), np.float64(204.0), np.float64(206.0), np.float64(211.0), np.float64(215.0), np.float64(222.0), np.float64(228.0), np.float64(233.0), np.float64(237.0), np.float64(243.0), np.float64(244.0), np.float64(245.0), np.float64(246.0), np.float64(247.0), np.float64(250.0
# ...

# %%
# Quantos preços diferentes existem
quantidade_precos = car_data['price'].nunique()
print(f"Existem {quantidade_precos} preços únicos")
# Out:
# Existem 3443 preços únicos

# %%
# Os 10 preços que mais aparecem
precos_comuns = car_data['price'].value_counts().head(10)
print(precos_comuns)
# Out:
# price
# 1.0       1596
# 6995.0    1438
# 5995.0    1310
# 4995.0    1248
# 3500.0    1240
# 7995.0    1232
# 5500.0    1230
# 4500.0    1216
# 8995.0    1098
# 6500.0    1056
# Name: count, dtype: int64

# %%
min_price = 1000  # ajuste de preço mínimo
common_prices_filtered = [p for p in precos_comuns.index if p is not None and p >= min_price]
cols = ['price','model_year','model','condition','odometer','transmission','type','paint_color']
dfp = car_data[car_data['price'].isin(common_prices_filtered)].copy()
dfp['odometer'] = pd.to_numeric(dfp['odometer'], errors='coerce')

# (opcional) evitar repetição do mesmo modelo no mesmo preço
dfp = dfp.sort_values(['price','model','odometer']).drop_duplicates(['price','model'], keep='first')

top3_per_price = (
    dfp
    .sort_values(['price','odometer','model_year'], ascending=[True,True,False])
    .groupby('price', group_keys=False)
    .head(3)[cols]
)

print(top3_per_price)
# Out:
#         price  model_year                model  condition  odometer  \
# 35482  3500.0      2008.0           ford focus  excellent     126.0
# 46913  3500.0         NaN       subaru outback       good     153.0
# 13605  3500.0      2004.0  jeep grand cherokee       good     154.0
# 23025  4500.0      1970.0           ford f-250       good       0.0
# 18405  4500.0      2010.0       toyota corolla  excellent       1.0
# 45243  4500.0      2004.0         toyota camry  excellent     100.0
# 34671  4995.0      2010.0     chevrolet malibu       good     152.0
# 929    4995.0      2003.0           ford f-150   like new     181.0
# 15227  4995.0      1998.0     chevrolet camaro       good   28170.0
# 27631  5500.0      2008.0        toyota sienna       good     145.0
# 25490  5500.0         NaN        nissan altima  excellent     170.0
# 20714  5500.0      2005.0      nissan frontier  excellent     200.0
# 11793  5995.0      2005.0            gmc yukon       good       0.0
# ...

# %%
print(car_data["is_4wd"].unique())
print(car_data["is_4wd"].dtype)
# Out:
# ['1.0' nan 'is_4wd' 1.0]
# object
